# %% [markdown]
# <a href="https://colab.research.google.com/github/tsoarescruz/word_cloud_colab/blob/main/ipynb/word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import pandas as pd

# %%
# !pip install newspaper3k
from newspaper import Article

# %%
#Load article
article = Article('https://pt.wikipedia.org/wiki/Gato', 'pt-br')
article.download()
article.parse()

# %%
from wordcloud import STOPWORDS, WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud()
wc.generate(article.text)
plt.imshow(wc, interpolation="antialiased")
plt.axis('off')
plt.show()

# %% [markdown]
# Parameters to WordCloud
#
# * background_color = Color of background
# * mac_words = The maximum number of unique words used
# * stopwords = stopword list
# * max_font_size = Maximum font size
# * random_state = To ensure that random numbers are generated in the same order, so the results will be the same even if generated several times
# * width = width size of the output
# * height = height size of the output

# %%
STOPWORDS = ['ver','principal','essa','vez','nas','mas','qual','principal','ele','ter','doença','pois','este','vez','ver principal','artigo principal','já','aos','pode','outro','artigo','desse','alguns','meio','entre','das','podem','esse','seu','também','são','quando','de', 'que','em','os','as','da','como','dos','ou','se','um','uma','para','na','ao','mais','por','não','ainda','muito','sua'] + list(STOPWORDS)

# %%
#mask_colors = ImageColorGenerator(mask)

wc = WordCloud(background_color="white", max_words=2000,
               stopwords=STOPWORDS, max_font_size=256,
               random_state=42, width=500, height=500)
wc.generate(article.text)
plt.imshow(wc, interpolation="kaiser")
plt.axis('off')
plt.show()

# %% [markdown]
# Matplot docs
#
# ```
# # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html?highlight=imshow#matplotlib.pyplot.imshow
#
# ```

# %% [markdown]
# Customized Mask

# %%
from PIL import Image
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7da08b44-4d10-4871-a0f8-d5b8d86fe172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7da08b44-4d10-4871-a0f8-d5b8d86fe172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving istockphoto-1177483805-1024x1024.jpeg to istockphoto-1177483805-1024x1024 (1).jpeg

# %% [markdown]
# Url to this image
#
# ```
# https://www.istockphoto.com/br/foto/gato-brit%C3%A2nico-f%C3%AAmea-azul-de-shorthair-no-branco-gm1177483805-328739891
#
# ```

# %%
mask = np.array(Image.open('istockphoto-1177483805-1024x1024.jpeg'))
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0])
wc.generate(article.text)
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
from wordcloud import ImageColorGenerator

# %%
mask_colors = ImageColorGenerator(mask)
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0], color_func=mask_colors)
wc.generate(article.text)
plt.figure( figsize=(80,40) ) #ajustar tamanho imagem
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.savefig('gato.jpg')

# %%
plt.savefig('cat_word_cloud.jpg')
